# %%
import pandas as pd

diet_df = pd.read_csv('diet.csv')
diet_df
# Out:
#              name emoji  Calories (kcal)  Carbohydrates (g)  Total Sugar (g)  \
# 0          grapes     🍇             0.69             0.1810           0.1548
# 1           melon     🍈             0.28             0.0658           0.0569
# 2      watermelon     🍉             0.30             0.0755           0.0620
# 3       tangerine     🍊             0.53             0.1334           0.1058
# 4           lemon     🍋             0.29             0.0932           0.0250
# 5          banana     🍌             0.89             0.2284           0.1223
# 6       pineapple     🍍             0.50             0.1312           0.0985
# 7       red apple     🍎             0.63             0.1522           0.1168
# 8     green apple     🍏             0.58             0.1361           0.0959
# 9            pear     🍐             0.57             0.1523           0.0975
# 10          peach     🍑             0.39             0.0954           0.0839
# ...

# %% [markdown]
# ### Média e desvio padrão dos carboidratos.

# %%
diet_df["Carbohydrates (g)"].mean()
# Out:
# 0.23735862068965513

# %%
diet_df["Carbohydrates (g)"].median()
# Out:
# 0.1607

# %%
diet_df["Carbohydrates (g)"].std()
# Out:
# 0.23227301996050448

# %% [markdown]
# ### Média e desvio padrão das proteinas

# %%
diet_df["Protein (g)"].mean()
# Out:
# 0.05014827586206896

# %%
diet_df["Protein (g)"].median()
# Out:
# 0.02005

# %%
diet_df["Protein (g)"].std()
# Out:
# 0.06771854093561733

# %% [markdown]
# ### Boxplot dos carboidratos

# %%
diet_df.boxplot(column = "Carbohydrates (g)")

# %%
diet_df["Carbohydrates (g)"].describe()
# Out:
# count    58.000000
# mean      0.237359
# std       0.232273
# min       0.000000
# 25%       0.068225
# 50%       0.160700
# 75%       0.300900
# max       0.980000
# Name: Carbohydrates (g), dtype: float64

# %% [markdown]
# ### Boxplot das proteinas

# %%
diet_df.boxplot(column = "Protein (g)")

# %%
diet_df["Protein (g)"].describe()
# Out:
# count    58.000000
# mean      0.050148
# std       0.067719
# min       0.000000
# 25%       0.006825
# 50%       0.020050
# 75%       0.069000
# max       0.274800
# Name: Protein (g), dtype: float64

# %% [markdown]
# ### Comparação da distribuição entre carboidratos e proteinas dos alimentos

# %%
diet_df.boxplot(column = ["Carbohydrates (g)", "Protein (g)"])
